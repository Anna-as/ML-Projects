# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
data= pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %% [markdown]
# # Plots of Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(data, hue= 'target')

# %% [markdown]
# # Linear Regression

# %%
def reg(xlabel,ylabel):
    xlabel="sepal length (cm)"
    ylabel="sepal width (cm)"
    x=data[xlabel].values
    y=data[ylabel].values
    sns.scatterplot(xlabel,ylabel,data=data, hue='target')
    plt.show()
    x=x.reshape(-1,1)
    y=y.reshape(-1,1)
    from sklearn.model_selection import train_test_split
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.10)
    from sklearn.linear_model import LinearRegression
    abc=LinearRegression()
    abc.fit(xtrain,ytrain)
    abc.intercept_
    abc.coef_
    xpredict=abc.predict(xtrain)
    plt.scatter(xtrain,ytrain)
    plt.plot(xtrain,xpredict,'r')
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.show()
    ypredict = abc.predict(xtest)
    plt.plot(xtest,ypredict,'r')
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.show()
    from sklearn import metrics  
    print('Mean Absolute Error of training data:', 
          metrics.mean_absolute_error(ytrain, xpredict)) 
    print('Mean Absolute Error of testing data:', 
          metrics.mean_absolute_error(ytest, ypredict))

# %% [markdown]
# ### Model1 with sepal length and sepal width as parameters

# %%
reg("sepal length (cm)","sepal width (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.32902246097995264
# Mean Absolute Error of testing data: 0.3564781922978572

# %% [markdown]
# ### Model2 with sepal length and petal length as parameters

# %%
reg("sepal length (cm)","petal length (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.32472331647451813
# Mean Absolute Error of testing data: 0.38080708698520394

# %% [markdown]
# ### Model3 with sepal length and petal width as parameters

# %%
reg("sepal length (cm)","petal width (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.3298300439058241
# Mean Absolute Error of testing data: 0.34549314805754444

# %% [markdown]
# ### Model4 with sepal width and sepal length as parameters

# %%
reg("sepal width (cm)","sepal length (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.3366099399134074
# Mean Absolute Error of testing data: 0.2914318534559618

# %% [markdown]
# ### Model5 with sepal width and petal length as parameters

# %%
reg("sepal width (cm)","petal length (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.32509662835204384
# Mean Absolute Error of testing data: 0.3755191493938279

# %% [markdown]
# ### Model6 with sepal width and petal width as parameters

# %%
reg("sepal width (cm)","petal widgth (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.33311666205860047
# Mean Absolute Error of testing data: 0.31835712158914486

# %% [markdown]
# ### Model7 with petal length and sepal length as parameters

# %%
reg("petal length (cm)","sepal length (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.32786069704724025
# Mean Absolute Error of testing data: 0.36352464833730413

# %% [markdown]
# ### Model8 with petal length and sepal width as parameters

# %%
reg("petal length (cm)","sepal width (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.33044026333043947
# Mean Absolute Error of testing data: 0.3473398099276924

# %% [markdown]
# ### Model9 with petal length and petal width as parameters

# %%
reg("petal length (cm)","petal width (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.3357491254251886
# Mean Absolute Error of testing data: 0.28538921494209146

# %% [markdown]
# ## Model 10 with petal width and sepal length as parameters

# %%
reg("petal width (cm)","sepal length (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.330901399270403
# Mean Absolute Error of testing data: 0.3358655096441075

# %% [markdown]
# ## Model 11 with petal width and sepal width as parameters

# %%
reg("petal width (cm)","sepal width (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.3139727276564012
# Mean Absolute Error of testing data: 0.49225194169896863

# %% [markdown]
# ## Model 12 with petal width and petal length as parameters

# %%
reg("petal width (cm)","petal length (cm)")
# Out:
# C:\Users\91735\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean Absolute Error of training data: 0.3307450869017036
# Mean Absolute Error of testing data: 0.33826278352245587

# %% [markdown]
# #### Based on these results,petal length is most predictive to find petal width since its mean square error is the least.
# #### Mean Square Error of:
# #### Model1 with sepal length and sepal width as parameters=0.3564781922978572
# #### Model2 with sepal length and petal length as parameters=0.38080708698520394
# #### Model3 with sepal length and petal width as parameters=0.34549314805754444
# #### Model4 with sepal width and sepal length as parameters=0.34549314805754444
# #### Model5 with sepal width and petal length as parameters=0.3755191493938279
# #### Model6 with sepal width and petal width as parameters=0.31835712158914486
# #### Model7 with petal length and sepal length as parameters=0.36352464833730413
# #### Model8 with petal length and sepal width as parameters=0.3473398099276924
# #### Model9 with petal length and petal width as parameters=0.28538921494209146
# #### Model 10 with petal width and sepal length as parameters=0.3358655096441075
# #### Model 11 with petal width and sepal width as parameters=0.49225194169896863
# #### Model 12 with petal width and petal length as parameters=0.33826278352245587
